# %%
import pandas as pd
import seaborn as sn
df=pd.read_csv("heart_disease.csv")
df.columns
# Out:
# Index(['age', 'sex', 'chest_pain_type', 'resting bp s', 'cholesterol',
#        'fasting blood sugar', 'resting ecg', 'heart_rate', 'exercise',
#        'oldpeak', 'ST slope', 'target'],
#       dtype='object')

# %% [markdown]
# # One Way Anova

# %%
from scipy.stats import f_oneway
import statsmodels.api as sms
from statsmodels.formula.api import ols
from statsmodels.stats.anova import AnovaRM 
# %matplotlib inline

# %%
df.boxplot('age', by='sex')
# Out:
# <Axes: title={'center': 'age'}, xlabel='sex'>

# %%
new=ols('chest_pain_type ~ sex',data=df).fit()
an=sms.stats.anova_lm(new,type=2)
an
# Out:
#               df       sum_sq    mean_sq          F    PR(>F)
# sex          1.0    19.932190  19.932190  23.201726  0.000002
# Residual  1188.0  1020.589659   0.859082        NaN       NaN

# %% [markdown]
# # Two ways Anova

# %%
df.columns
# Out:
# Index(['age', 'sex', 'chest_pain_type', 'resting bp s', 'cholesterol',
#        'fasting blood sugar', 'resting ecg', 'heart_rate', 'exercise',
#        'oldpeak', 'ST slope', 'target'],
#       dtype='object')

# %%
ax=sn.boxplot(x="chest_pain_type", y="sex", data=df)

# %%
ax=sn.boxplot(x="sex", y="exercise", data=df)
